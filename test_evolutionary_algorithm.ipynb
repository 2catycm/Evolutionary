# %%
import evolutionary_algorithm as ea
ea.abstract_algorithms
# Out:
# <module 'abstract_algorithms' from '/work/ssc-07/yecanming/repo/P_CS_Labs/Student-Involution-Algorithms/evolutionary_algorithm/abstract_algorithms.py'>

# %%
import benchmark_funs as bf
problem = bf.NegativeProxyObjective(bf.Sphere(30))

# %%
import torch
mutation_ea = ea.mutation_based_ea.MutationBasedEA(problem)
normal_choice = torch.Tensor([0, 1, 4, 3, 1]).to(torch.int64)

# %%
# %timeit mutation_ea(normal_choice)

# %%
# mutation_ea = torch.compile(mutation_ea)
# Out:
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda-11.8'

# %%
# %timeit mutation_ea(normal_choice)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# ~/team/package_managers/anaconda3/envs/torch2.0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in _compile(code, globals, locals, builtins, compiler_fn, one_graph, export, hooks, frame)
#     323             try:
# --> 324                 out_code = transform_code_object(code, transform)
#     325                 orig_code_map[out_code] = code
#
# ~/team/package_managers/anaconda3/envs/torch2.0/lib/python3.9/site-packages/torch/_dynamo/bytecode_transformation.py in transform_code_object(code, transformations, safe)
#     360
# --> 361     transformations(instructions, code_options)
#     362
#
# ~/team/package_managers/anaconda3/envs/torch2.0/lib/python3.9/site-packages/torch/_dynamo/convert_frame.py in transform(instructions, code_options)
#     310         )
# --> 311         tracer.run()
# ...

# %%
best_x, history = mutation_ea(normal_choice)

# %%
from matplotlib import pyplot as plt
plt.plot(history)
plt.savefig('runs/test/test_ea.png')

# %%
# device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# problem = problem.to(device)
# mutation_ea = ea.mutation_based_ea.MutationBasedEA(problem).to(device)
# normal_choice = torch.Tensor([0, 1, 4, 3, 1]).to(torch.int64).to(device)
# problem.
